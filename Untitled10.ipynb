# %%
# !pip install -Uqq fastai

# %%
from fastai.tabular.all import *

# %%
df = pd.read_csv('/content/train.csv')
df.drop(['PassengerId'], axis=1,inplace=True)
df.loc[len(df),'Survived'] = 0.0
df.tail()
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 887       1.0     1.0              Graham, Miss. Margaret Edith  female  19.0
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1.0     1.0                     Behr, Mr. Karl Howell    male  26.0
# 890       0.0     3.0                       Dooley, Mr. Patrick    male  32.0
# 891       0.0     NaN                                       NaN     NaN   NaN
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked
# 887    0.0    0.0      112053  30.00   B42        S
# 888    1.0    2.0  W./C. 6607  23.45   NaN        S
# 889    0.0    0.0      111369  30.00  C148        C
# 890    0.0    0.0      370376   7.75   NaN        Q
# 891    NaN    NaN         NaN    NaN   NaN      NaN

# %%
dls = TabularDataLoaders.from_csv('/content/train.csv', y_names="Survived",
    cat_names = ['Name', 'Pclass', 'Sex', 'SibSp', 'Parch','Ticket','Cabin','Embarked'],
    cont_names = ['Age','Fare'],
    procs = [Categorify, FillMissing, Normalize])

# %%
splits = RandomSplitter(valid_pct=0.2)(range_of(df))

# %%
to = TabularPandas(df, procs=[Categorify, FillMissing,Normalize],
                   cat_names = [ 'Name', 'Pclass', 'Sex', 'SibSp', 'Parch','Ticket','Cabin','Embarked'],
                   cont_names = ['Age','Fare'],
                   y_names='Survived',
                   splits=splits)

# %%
to.xs.iloc[:2]
# Out:
#      Name  Pclass  Sex  SibSp  Parch  Ticket  Cabin  Embarked  Age_na  \
# 625   795       1    2      1      1     456    111         3       1
# 209    95       1    2      1      1      18      9         1       1
#
#      Fare_na       Age      Fare
# 625        1  2.445559 -0.005297
# 209        1  0.832211 -0.032462

# %%
dls = to.dataloaders(bs=64)

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#       <th>Age_na</th>
#       <th>Fare_na</th>
#       <th>Age</th>
#       <th>Fare</th>
#       <th>Survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Troupiansky, Mr. Moses Aaron</td>
#       <td>2.0</td>
#       <td>male</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>233639</td>
#       <td>#na#</td>
#       <td>S</td>
#       <td>False</td>
#       <td>False</td>
#       <td>23.000000</td>
#       <td>13.000000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Nicola-Yarred, Miss. Jamila</td>
#       <td>3.0</td>
#       <td>female</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>2651</td>
# ...

# %%
learn = tabular_learner(dls, metrics=accuracy)

# %%
learn.fit_one_cycle(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.689600</td>
#       <td>0.225805</td>
#       <td>0.685393</td>
#       <td>00:00</td>
# ...

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#       <th>Age_na</th>
#       <th>Fare_na</th>
#       <th>Age</th>
#       <th>Fare</th>
# ...

# %%
learn

# %%
df_test = pd.read_csv('/content/test.csv')
dl = learn.dls.test_dl(df_test)

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
learn.get_preds(dl=dl)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (tensor([[-9.5837e-02],
#          [ 2.1122e-01],
#          [ 2.5514e-02],
#          [-5.9811e-02],
#          [ 2.9790e-01],
#          [-4.2001e-02],
#          [ 2.1864e-01],
#          [ 3.6016e-01],
#          [ 1.5636e-01],
#          [-7.2956e-02],
#          [-8.3284e-02],
#          [ 1.9646e-01],
#          [ 6.1480e-01],
#          [ 5.8293e-02],
#          [ 2.1661e-01],
# ...
